# %% [markdown]
# ### 1.Import the pandas library
# Read the data company.csv in pandas

# %%
import pandas as pd
df = pd.read_csv("company.csv")
print(df.to_string())
# Out:
#                        Company   Age  Salary       Place Country
# 0                          TCS  20.0     NaN     Chennai   India
# 1                      Infosys  30.0     NaN      Mumbai   India
# 2                          TCS  35.0  2300.0    Calcutta   India
# 3                      Infosys  40.0  3000.0       Delhi   India
# 4                          TCS  23.0  4000.0      Mumbai   India
# 5                      Infosys   NaN  5000.0    Calcutta   India
# 6                          TCS   NaN  6000.0     Chennai   India
# 7                      Infosys  23.0  7000.0      Mumbai   India
# 8                          TCS  34.0  8000.0    Calcutta   India
# 9                          CTS  45.0  9000.0       Delhi   India
# 10                         CTS  23.0     NaN      Mumbai   India
# 11                         CTS  34.0  1089.0    Calcutta   India
# 12                         CTS  45.0     NaN     Chennai   India
# ...

# %% [markdown]
# ### 2.Find the dimension of given data

# %%
df.size
# Out:
# 745

# %%
df.shape
# Out:
# (149, 5)

# %%
df.ndim
# Out:
# 2

# %% [markdown]
# Syntax: dataframe.size
# Return : Returns size of dataframe/series which is equivalent to total number of elements. That is rows x columns.
#
# Syntax: dataframe.shape
# Return : Returns tuple of shape (Rows, columns) of dataframe/series
#
# Syntax: dataframe.ndim
# Return : Returns dimension of dataframe/series. 1 for one dimension (series), 2 for two dimension (dataframe)

# %% [markdown]
# ### 3.List down all the columns in data frame

# %%
df.columns.values.tolist()
# Out:
# ['Company', 'Age', 'Salary', 'Place', 'Country']

# %%
column_name = list(df)
column_name
# Out:
# ['Company', 'Age', 'Salary', 'Place', 'Country']

# %% [markdown]
# ### 4.List the top 10 rows in datframe

# %%
df.head(10) #default gives 5
# Out:
#    Company   Age  Salary     Place Country
# 0      TCS  20.0     NaN   Chennai   India
# 1  Infosys  30.0     NaN    Mumbai   India
# 2      TCS  35.0  2300.0  Calcutta   India
# 3  Infosys  40.0  3000.0     Delhi   India
# 4      TCS  23.0  4000.0    Mumbai   India
# 5  Infosys   NaN  5000.0  Calcutta   India
# 6      TCS   NaN  6000.0   Chennai   India
# 7  Infosys  23.0  7000.0    Mumbai   India
# 8      TCS  34.0  8000.0  Calcutta   India
# 9      CTS  45.0  9000.0     Delhi   India

# %% [markdown]
# ### 5.List the last 15 rows in datframe

# %%
df.tail(15) # default is 5
# Out:
#                        Company   Age  Salary      Place Country
# 134  Tata Consultancy Services  31.0  8345.0     Mumbai   India
# 135                        CTS  40.0  9284.0   Calcutta   India
# 136                        NaN   NaN     NaN      Delhi   India
# 137                        CTS  31.0  2034.0     Mumbai   India
# 138                        CTS  44.0  3033.0     Cochin   India
# 139                 Congnizant  22.0  2934.0      Noida   India
# 140                    Infosys  44.0  4034.0  Hyderabad   India
# 141                        TCS  33.0  5034.0   Calcutta   India
# 142            Infosys Pvt Lmt  22.0  8202.0     Mumbai   India
# 143                        TCS  33.0  9024.0   Calcutta   India
# 144                    Infosys  22.0  8787.0   Calcutta   India
# 145                    Infosys  44.0  4034.0      Delhi   India
# 146                        TCS  33.0  5034.0     Mumbai   India
# 147                    Infosys  22.0  8202.0     Cochin   India
# ...

# %% [markdown]
# ### 6.Find the number of rows in dataframe

# %%
print(df.shape[0])
print(df.shape[1])
# Out:
# 149
# 5

# %%
print(len(df.axes[0]))
print(len(df.axes[1]))
# Out:
# 149
# 5

# %%
print(df.axes)
print(df.axes[0])
print(df.axes[1])
# Out:
# [RangeIndex(start=0, stop=149, step=1), Index(['Company', 'Age', 'Salary', 'Place', 'Country'], dtype='object')]
# RangeIndex(start=0, stop=149, step=1)
# Index(['Company', 'Age', 'Salary', 'Place', 'Country'], dtype='object')

# %%
print(len(df.index))
print(len(df.columns))
# Out:
# 149
# 5

# %%
print(df.index)
print(df.columns)
# Out:
# RangeIndex(start=0, stop=149, step=1)
# Index(['Company', 'Age', 'Salary', 'Place', 'Country'], dtype='object')

# %%
len(df)
# Out:
# 149

# %%
df[df.columns[0]].count() # non NAN count
# Out:
# 140

# %% [markdown]
# ### 7.Check the information of dataframe

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Company  140 non-null    object
#  1   Age      130 non-null    float64
#  2   Salary   124 non-null    float64
#  3   Place    134 non-null    object
#  4   Country  148 non-null    object
# dtypes: float64(2), object(3)
# memory usage: 5.9+ KB

# %% [markdown]
# ### 8.Check the basic Statistics of Dataframe. Give your inference from the stats

# %%
df.describe() # right ans
# Out:
#               Age       Salary
# count  130.000000   124.000000
# mean    30.484615  5312.467742
# std     11.096640  2573.764683
# min      0.000000  1089.000000
# 25%     22.000000  3030.000000
# 50%     32.500000  5000.000000
# 75%     37.750000  8000.000000
# max     54.000000  9876.000000

# %% [markdown]
# ### 9.Retrieve 20 to 100 rows and Company and age usig iloc

# %%
df.iloc[20:101,0:2]
# Out:
#      Company   Age
# 20       TCS  37.0
# 21   Infosys  50.0
# 22       TCS  21.0
# 23   Infosys   NaN
# 24       TCS   NaN
# ..       ...   ...
# 96       TCS   NaN
# 97   Infosys  22.0
# 98       TCS  33.0
# 99       CTS  44.0
# 100      CTS  22.0
#
# [81 rows x 2 columns]

# %% [markdown]
# ### 10.Retrieve 20 to 100 rows and Company and age usig loc

# %%
df.loc[20:100,['Company','Age']]
# Out:
#      Company   Age
# 20       TCS  37.0
# 21   Infosys  50.0
# 22       TCS  21.0
# 23   Infosys   NaN
# 24       TCS   NaN
# ..       ...   ...
# 96       TCS   NaN
# 97   Infosys  22.0
# 98       TCS  33.0
# 99       CTS  44.0
# 100      CTS  22.0
#
# [81 rows x 2 columns]

# %% [markdown]
# ### 11.Chage the data in 100 row and Place as 'Noida'

# %%
ChgVal = df.at[100, 'Place'] = 'Noida'
print(df.iloc[100])
print(ChgVal)
# Out:
# Company      CTS
# Age         22.0
# Salary       NaN
# Place      Noida
# Country    India
# Name: 100, dtype: object
# Noida

# %% [markdown]
# ### 12.Change the column 'Place' to 'City'

# %%
df.rename(columns = {'Place':'City'},inplace = True)

# %% [markdown]
# ### 13.List down the unique data in each columns and find length of unique data

# %%
for col in df:
    print(df[col].unique())
# Out:
# ['TCS' 'Infosys' 'CTS' nan 'Tata Consultancy Services' 'Congnizant'
#  'Infosys Pvt Lmt']
# [20. 30. 35. 40. 23. nan 34. 45. 18. 22. 32. 37. 50. 21. 46. 36. 26. 41.
#  24. 25. 43. 19. 38. 51. 31. 44. 33. 17.  0. 54.]
# [  nan 2300. 3000. 4000. 5000. 6000. 7000. 8000. 9000. 1089. 1234. 3030.
#  3045. 3184. 4824. 5835. 7084. 8943. 8345. 9284. 9876. 2034. 7654. 2934.
#  4034. 5034. 8202. 9024. 4345. 6544. 6543. 3234. 4324. 5435. 5555. 8787.
#  3454. 5654. 5009. 5098. 3033.]
# ['Chennai' 'Mumbai' 'Calcutta' 'Delhi' 'Podicherry' 'Cochin' nan 'Noida'
#  'Hyderabad' 'Bhopal' 'Nagpur' 'Pune']
# ['India' nan]

# %%
df.nunique()
# Out:
# Company     6
# Age        29
# Salary     40
# City       11
# Country     1
# dtype: int64

# %% [markdown]
# ### 14.Rename all the possible labels of column in Company as three labels
# TCS
# CTS
# Infosys

# %%
df['Company'] = df['Company'].replace(['Infosys Pvt Lmt','Congnizant','Tata Consultancy Services'],['Infosys','CTS', 'TCS'])
print(df['Company'])
df.nunique()
# Out:
# 0          TCS
# 1      Infosys
# 2          TCS
# 3      Infosys
# 4          TCS
#         ...
# 144    Infosys
# 145    Infosys
# 146        TCS
# 147    Infosys
# 148        NaN
# Name: Company, Length: 149, dtype: object
# Company     3
# Age        29
# Salary     40
# City       11
# Country     1
# dtype: int64

# %% [markdown]
# ### 15.Where ever you see age as 0 replace with NA
#
# ##Hint df[df.Age==20] = np.isnan

# %%
import numpy as np
df[df.Age==0] = np.isnan
df
# Out:
#      Company   Age  Salary      City Country
# 0        TCS  20.0     NaN   Chennai   India
# 1    Infosys  30.0     NaN    Mumbai   India
# 2        TCS  35.0  2300.0  Calcutta   India
# 3    Infosys  40.0  3000.0     Delhi   India
# 4        TCS  23.0  4000.0    Mumbai   India
# ..       ...   ...     ...       ...     ...
# 144  Infosys  22.0  8787.0  Calcutta   India
# 145  Infosys  44.0  4034.0     Delhi   India
# 146      TCS  33.0  5034.0    Mumbai   India
# 147  Infosys  22.0  8202.0    Cochin   India
# 148      NaN   NaN     NaN       NaN     NaN
#
# [149 rows x 5 columns]

# %% [markdown]
# ### 16.Check how many duplicated data is there?

# %%
df.duplicated().sum()
# Out:
# 13

# %% [markdown]
# ### 17.Remove all duplicated rowise data

# %%
df[~df.duplicated()]
# Out:
#      Company   Age  Salary       City Country
# 0        TCS  20.0     NaN    Chennai   India
# 1    Infosys  30.0     NaN     Mumbai   India
# 2        TCS  35.0  2300.0   Calcutta   India
# 3    Infosys  40.0  3000.0      Delhi   India
# 4        TCS  23.0  4000.0     Mumbai   India
# ..       ...   ...     ...        ...     ...
# 140  Infosys  44.0  4034.0  Hyderabad   India
# 141      TCS  33.0  5034.0   Calcutta   India
# 142  Infosys  22.0  8202.0     Mumbai   India
# 143      TCS  33.0  9024.0   Calcutta   India
# 148      NaN   NaN     NaN        NaN     NaN
#
# [136 rows x 5 columns]

# %%
df.drop_duplicates()
# Out:
#      Company   Age  Salary       City Country
# 0        TCS  20.0     NaN    Chennai   India
# 1    Infosys  30.0     NaN     Mumbai   India
# 2        TCS  35.0  2300.0   Calcutta   India
# 3    Infosys  40.0  3000.0      Delhi   India
# 4        TCS  23.0  4000.0     Mumbai   India
# ..       ...   ...     ...        ...     ...
# 140  Infosys  44.0  4034.0  Hyderabad   India
# 141      TCS  33.0  5034.0   Calcutta   India
# 142  Infosys  22.0  8202.0     Mumbai   India
# 143      TCS  33.0  9024.0   Calcutta   India
# 148      NaN   NaN     NaN        NaN     NaN
#
# [136 rows x 5 columns]

# %% [markdown]
# ### 18.Remove the column 'Country'

# %%
del df['Country']
df
# Out:
#      Company   Age  Salary      City
# 0        TCS  20.0     NaN   Chennai
# 1    Infosys  30.0     NaN    Mumbai
# 2        TCS  35.0  2300.0  Calcutta
# 3    Infosys  40.0  3000.0     Delhi
# 4        TCS  23.0  4000.0    Mumbai
# ..       ...   ...     ...       ...
# 144  Infosys  22.0  8787.0  Calcutta
# 145  Infosys  44.0  4034.0     Delhi
# 146      TCS  33.0  5034.0    Mumbai
# 147  Infosys  22.0  8202.0    Cochin
# 148      NaN   NaN     NaN       NaN
#
# [149 rows x 4 columns]

# %% [markdown]
# ### 19.Remove the row number 137

# %%
df.drop(137)
# Out:
#      Company   Age  Salary      City
# 0        TCS  20.0     NaN   Chennai
# 1    Infosys  30.0     NaN    Mumbai
# 2        TCS  35.0  2300.0  Calcutta
# 3    Infosys  40.0  3000.0     Delhi
# 4        TCS  23.0  4000.0    Mumbai
# ..       ...   ...     ...       ...
# 144  Infosys  22.0  8787.0  Calcutta
# 145  Infosys  44.0  4034.0     Delhi
# 146      TCS  33.0  5034.0    Mumbai
# 147  Infosys  22.0  8202.0    Cochin
# 148      NaN   NaN     NaN       NaN
#
# [148 rows x 4 columns]

# %% [markdown]
# ### 20.Find number of each labels in Company

# %%
df.groupby('Company').size()
# Out:
# Company
# <ufunc 'isnan'>     6
# CTS                36
# Infosys            45
# TCS                53
# dtype: int64

# %% [markdown]
# ### 21.Find number of each labels in City

# %%
df.groupby('City').size()
# Out:
# City
# <ufunc 'isnan'>     6
# Bhopal              1
# Calcutta           31
# Chennai            13
# Cochin             12
# Delhi              13
# Hyderabad           8
# Mumbai             36
# Nagpur              1
# Noida               9
# Podicherry          2
# Pune                2
# dtype: int64

# %% [markdown]
# ### 22.Find Number of Null Values in each column

# %%
df.isna().sum()
# Out:
# Company     9
# Age        19
# Salary     25
# City       15
# dtype: int64

# %% [markdown]
# ### 23.Remove all Null values in Salary

# %%
df.dropna()
# Out:
#      Company   Age  Salary      City
# 2        TCS  35.0  2300.0  Calcutta
# 3    Infosys  40.0  3000.0     Delhi
# 4        TCS  23.0  4000.0    Mumbai
# 7    Infosys  23.0  7000.0    Mumbai
# 8        TCS  34.0  8000.0  Calcutta
# ..       ...   ...     ...       ...
# 143      TCS  33.0  9024.0  Calcutta
# 144  Infosys  22.0  8787.0  Calcutta
# 145  Infosys  44.0  4034.0     Delhi
# 146      TCS  33.0  5034.0    Mumbai
# 147  Infosys  22.0  8202.0    Cochin
#
# [93 rows x 4 columns]

# %% [markdown]
# ### 24.Replace the Null values in Comapany with mode

# %%
df['Company'].fillna(df['Company'].mode()[0])
# Out:
# 0          TCS
# 1      Infosys
# 2          TCS
# 3      Infosys
# 4          TCS
#         ...
# 144    Infosys
# 145    Infosys
# 146        TCS
# 147    Infosys
# 148        TCS
# Name: Company, Length: 149, dtype: object

# %% [markdown]
# ### 25.Replace the null value in Salary with median

# %%
df['Salary'] = df['Salary'].fillna(df['Salary'].median())
print(df['Salary'])
# Out:
# 0      5000.0
# 1      5000.0
# 2      2300.0
# 3      3000.0
# 4      4000.0
#         ...
# 144    8787.0
# 145    4034.0
# 146    5034.0
# 147    8202.0
# 148    5000.0
# Name: Salary, Length: 149, dtype: float64

# %% [markdown]
# ### 26.Replace the null value in age with mean

# %%
df['Age'] = df['Age'].fillna(df['Age'].mean())
print(df['Age'])
# Out:
# 0      20.000000
# 1      30.000000
# 2      35.000000
# 3      40.000000
# 4      23.000000
#          ...
# 144    22.000000
# 145    44.000000
# 146    33.000000
# 147    22.000000
# 148    30.484615
# Name: Age, Length: 149, dtype: float64

# %% [markdown]
# ### 27.Filter the data with age>40 and Salary<5000

# %%
df.loc[(df['Age'] > 40) & (df['Salary'] < 5000)]
# Out:
#      Company   Age  Salary      Place Country
# 21   Infosys  50.0  3184.0      Delhi   India
# 32   Infosys  45.0  4034.0   Calcutta   India
# 39   Infosys  41.0  3000.0     Mumbai   India
# 50   Infosys  41.0  3000.0    Chennai   India
# 57   Infosys  51.0  3184.0  Hyderabad   India
# 68   Infosys  43.0  4034.0     Mumbai   India
# 75   Infosys  44.0  3000.0     Cochin   India
# 86   Infosys  41.0  3000.0      Delhi   India
# 93   Infosys  54.0  3184.0     Mumbai   India
# 104  Infosys  44.0  4034.0      Delhi   India
# 122  Infosys  44.0  3234.0     Mumbai   India
# 129  Infosys  50.0  3184.0   Calcutta   India
# 138      CTS  44.0  3033.0     Cochin   India
# 140  Infosys  44.0  4034.0  Hyderabad   India
# 145  Infosys  44.0  4034.0      Delhi   India

# %% [markdown]
# ### 28.Draw the pie chart for place and Company

# %%
plot = df.Company.value_counts().plot(kind = 'pie')

# %%
df.City.value_counts().plot(kind = 'pie')
# Out:
# <AxesSubplot:ylabel='City'>

# %% [markdown]
# ### 29.Find the mean age with repective to the Company

# %%
df.groupby('Company')['Age'].mean()
# Out:
# Company
# CTS                          32.194444
# Congnizant                   21.500000
# Infosys                      32.241709
# Infosys Pvt Lmt              21.500000
# TCS                          28.752395
# Tata Consultancy Services    33.500000
# Name: Age, dtype: float64

# %% [markdown]
# ### 30.Draw an histogram chart for age, Salary

# %%
df.hist(['Age','Salary'])
# Out:
# array([[<AxesSubplot:title={'center':'Age'}>,
#         <AxesSubplot:title={'center':'Salary'}>]], dtype=object)

# %% [markdown]
# ### 31.Find the mean, count, median of salary with repective to the place

# %%
df.groupby('City')['Salary'].mean()
# Out:
# City
# Bhopal        7000.000000
# Calcutta      5028.363636
# Chennai       5876.142857
# Cochin        5048.923077
# Delhi         4801.857143
# Hyderabad     4537.125000
# Mumbai        4896.486486
# Nagpur        8000.000000
# Noida         4463.625000
# Podicherry    4782.666667
# Pune          7000.000000
# Name: Salary, dtype: float64

# %%
df.groupby('City')['Salary'].median()
# Out:
# City
# Bhopal        7000.0
# Calcutta      5000.0
# Chennai       5635.0
# Cochin        5000.0
# Delhi         4034.0
# Hyderabad     4517.0
# Mumbai        5000.0
# Nagpur        8000.0
# Noida         4500.0
# Podicherry    3030.0
# Pune          7000.0
# Name: Salary, dtype: float64

# %%
df.groupby('City')['Salary'].count()
# Out:
# City
# Bhopal         1
# Calcutta      33
# Chennai       14
# Cochin        13
# Delhi         14
# Hyderabad      8
# Mumbai        37
# Nagpur         1
# Noida          8
# Podicherry     3
# Pune           2
# Name: Salary, dtype: int64
